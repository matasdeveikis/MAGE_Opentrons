# %%
#Import opentrons and run
import sys
# !{sys.executable} -m pip install opentrons
# Out:
# Requirement already satisfied: opentrons in c:\users\owen\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: aionotify==0.2.0 in c:\users\owen\anaconda3\lib\site-packages (from opentrons) (0.2.0)
# Requirement already satisfied: pyserial==3.4 in c:\users\owen\anaconda3\lib\site-packages (from opentrons) (3.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\owen\anaconda3\lib\site-packages (from opentrons) (3.7.4.3)
# Requirement already satisfied: jsonschema<4,>=3.0.2 in c:\users\owen\anaconda3\lib\site-packages (from opentrons) (3.2.0)
# Requirement already satisfied: numpy>=1.15.1 in c:\users\owen\anaconda3\lib\site-packages (from opentrons) (1.16.4)
# Requirement already satisfied: opentrons-shared-data==4.0.0 in c:\users\owen\anaconda3\lib\site-packages (from opentrons) (4.0.0)
# Requirement already satisfied: urwid==1.3.1 in c:\users\owen\anaconda3\lib\site-packages (from opentrons) (1.3.1)
# Requirement already satisfied: pydantic==1.4 in c:\users\owen\anaconda3\lib\site-packages (from opentrons) (1.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\owen\anaconda3\lib\site-packages (from jsonschema<4,>=3.0.2->opentrons) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\owen\anaconda3\lib\site-packages (from jsonschema<4,>=3.0.2->opentrons) (0.14.11)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\owen\anaconda3\lib\site-packages (from jsonschema<4,>=3.0.2->opentrons) (0.17)
# Requirement already satisfied: setuptools in c:\users\owen\anaconda3\lib\site-packages (from jsonschema<4,>=3.0.2->opentrons) (41.0.1)
# Requirement already satisfied: six>=1.11.0 in c:\users\owen\anaconda3\lib\site-packages (from jsonschema<4,>=3.0.2->opentrons) (1.12.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\owen\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema<4,>=3.0.2->opentrons) (0.5.1)

# %%
import numpy as np
from opentrons import simulate
metadata = {'apiLevel': '2.7'}
protocol = simulate.get_protocol_api('2.7')
# Out:
# C:\Users\Owen\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\Owen\.opentrons\robot_settings.json not found. Loading defaults

# %%
#Labware
# Assume that we start with a P. putida strain that has edd deleted and posseses both Cas9 and recombinase plasmids

tiprack_20 = [
        protocol.load_labware(
            'opentrons_96_filtertiprack_20ul', str(s), '300ul Tips')
        for s in [3]]
tiprack_300 = [
        protocol.load_labware(
            'opentrons_96_tiprack_300ul', str(s), '300ul Tips')
        for s in [2]]

temp_hot = protocol.load_module('tempdeck', 4)                #For Heatshock
hot_plate = temp_hot.load_labware('corning_96_wellplate_360ul_flat')

bacteria_media = protocol.load_labware('nest_12_reservoir_15ml', 5)      #Bacterial Culture(A1) + LB_Media(A6)

temp_cold = protocol.load_module('tempdeck', 6) #For Heatshock
cold_plate = temp_cold.load_labware('corning_96_wellplate_360ul_flat')

storage_oligos = protocol.load_labware('opentrons_96_aluminumblock_generic_pcr_strip_200ul', 7)  #Stores Oligos
reagents = protocol.load_labware('opentrons_24_tuberack_generic_2ml_screwcap', 10)


# 384 well plate example
# ot_384 = protocol.load_labware('corning_384_wellplate_112ul_flat', 10)

temp_cold.set_temperature(4)
temp_hot.set_temperature(42)

#pipettes
p20 = protocol.load_instrument('p20_single_gen2', 'left', tip_racks=tiprack_20)
p300 = protocol.load_instrument('p300_single_gen2', 'right', tip_racks=tiprack_300)
protocol.max_speeds['Z'] = 10

#Reagents
Bacteria = bacteria_media.wells ('A1')
Media = bacteria_media.wells ('A6')
CRISPR_plasmid = reagents.wells ('A1') 
CaCL_1M = reagents.wells ('A2') 
PBS = reagents.wells ('A3')

# %%
# Variables
plasmid_conc = 20 * np.ones(1)
oligos = 96
growth_temp = 37

#Add cells to each strip
p300.distribute(50, Bacteria, storage_oligos.columns()[0:12], touch_tip=False, new_tip='once')

#Add CRISPR plasmid to each of the PCR strip containing different oligos
for i in range(1):
    p20.distribute(50/float(plasmid_conc), CRISPR_plasmid, storage_oligos.columns()[0:12], touch_tip=True, new_tip='always') # A1 is where the CRISPR plasmids are located on the tuberack
# Could we do touch_tip=False, new_tip='never' here to save on tips

# To-do - electroporation option

# Heat shock protocol - save tips from here?
# Adding 100mM of CaCl
p20.distribute(5, CaCL_1M, cold_plate.columns()[0:12], touch_tip=True, new_tip='once')

for i in range(0, 12):
    p300.pick_up_tip()   
    p300.transfer(45, storage_oligos.columns()[i], cold_plate.columns()[i], touch_tip=True, new_tip='never')
    p300.return_tip()
    
protocol.delay(minutes = 15) 

for i in range(0, 12):
    p300.pick_up_tip()   
    p300.transfer(45, cold_plate.columns()[i], hot_plate.columns()[i], touch_tip=True, new_tip='never')
    p300.return_tip()
    
# need to figure out how long the operation takes to subtract from this
protocol.delay(seconds = 90) 

for i in range(0, 12):
    p300.pick_up_tip()   
    p300.transfer(45, hot_plate.columns()[i], cold_plate.columns()[i], touch_tip=True, new_tip='never')
    p300.return_tip()
    
p300.distribute(270, Media, hot_plate.columns()[0:12], touch_tip=False, new_tip='once')
temp_hot.set_temperature(growth_temp)
protocol.delay(minutes = 5) 

for i in range(0, 12):
    p300.pick_up_tip()   
    p300.transfer(30, cold_plate.columns()[i], hot_plate.columns()[i], touch_tip=True, new_tip='never')
    p300.return_tip()
protocol.delay(minutes = 60)

# Step 2
protocol.pause('Replace tips and add agarose plates')
#change modules 
dilution_plate_1 = protocol.load_labware('corning_96_wellplate_360ul_flat', 1)   #1:10 Dilution from Heatshock Output
solid_agar_glucose = protocol.load_labware('axygen_1_reservoir_90ml', 8)       #Solid Agar pre-made on the reservoir
solid_agar_lupanine = protocol.load_labware('axygen_1_reservoir_90ml', 9)      #Solid Agar pre-made on the reservoir
dilution_plate_2 = protocol.load_labware('corning_96_wellplate_360ul_flat', 11)   #1:100 Dilution from Heatshock Output

protocol.resume()

#Add 270ul to dilution_plate_1 and dilution_plate_2
p300.distribute(270, PBS, dilution_plate_1.columns()[0:12], touch_tip=False, new_tip='once')
p300.distribute(270, PBS, dilution_plate_2.columns()[0:12], touch_tip=False, new_tip='once')

for i in range(0, 12):
    p300.pick_up_tip()   
    p300.transfer(30, hot_plate.columns()[i], dilution_plate_1.columns()[i], touch_tip=True, new_tip='never')
    p300.return_tip()

for i in range(0,12):
    p300.pick_up_tip()   
    p300.transfer(30, dilution_plate_1.columns()[i], dilution_plate_2.columns()[i], touch_tip=True, new_tip='never', mix_before=(3,50))
    p300.return_tip()
#p300.distribute(180, reservoir.wells('H1'), dilution_plate_1.columns()[0:12])

#Take 20ul from PCR_STRIP that has undergone heat shock and place in dilution_plate_1 + MIX

#Insert 180ul of LB_Media(H1) from bacteria_media into each well of dilution_plate_2

#Take 20ul from dilution_plate_1 that is now in 1:10 dilution and place in dilution_plate_2 + MIX to get 1:100 dilution

##OUTPUT: in dilution_plate_2 in each well, we have bacterial cells in 1:100 dilution with different oligos

#PLATING: Spot 10ul from dilution_plate_2 into solid_agar_glucose

#PLATING: Spot 10ul from dilution_plate_2 into solid_agar_lupanine

for line in protocol.commands(): 
        print(line)
# Out:
# Setting Temperature Module temperature to 4.0 °C (rounded off to nearest integer)
# Setting Temperature Module temperature to 42.0 °C (rounded off to nearest integer)
# Distributing 50.0 from A1 of NEST 12 Well Reservoir 15 mL on 5 to A1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7
# Transferring 50.0 from A1 of NEST 12 Well Reservoir 15 mL on 5 to A1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7
# Picking up tip from A1 of 300ul Tips on 2
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into A1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into C1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into F1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into H1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into A2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into C2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into F2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into H2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into A3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into C3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into E3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into F3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into H3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into A4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into B4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into C4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into F4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into G4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into H4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into A5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into C5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into D5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into F5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into H5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into A6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into C6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into F6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into H6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into A7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into C7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into F7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into H7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into A8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into C8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into E8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into F8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into H8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into A9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into B9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into C9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into F9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into G9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into H9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into A10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into C10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into D10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into F10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into H10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into A11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into C11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into F11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into H11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into A12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into B12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 270.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into C12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into D12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into E12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into F12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Dispensing 50.0 uL into G12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 70.0 uL from A1 of NEST 12 Well Reservoir 15 mL on 5 at 92.86 uL/sec
# Dispensing 50.0 uL into H12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Distributing 2.5 from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 to A1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7
# Transferring 2.5 from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 to A1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7
# Picking up tip from A1 of 300ul Tips on 3
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H2 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H3 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H4 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H5 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H6 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H7 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H8 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H9 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H10 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 18.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H11 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into A12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into B12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into C12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 13.5 uL from A1 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into D12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into E12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into F12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into G12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Dispensing 2.5 uL into H12 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Distributing 5.0 from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 to A1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6
# Transferring 5.0 from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 to A1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6
# Picking up tip from B1 of 300ul Tips on 3
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A2 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B2 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C2 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D2 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E2 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F2 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G2 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H2 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A3 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B3 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C3 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D3 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E3 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F3 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G3 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H3 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A4 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B4 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C4 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D4 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E4 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F4 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G4 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H4 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A5 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B5 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C5 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D5 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E5 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F5 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G5 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H5 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A6 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B6 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C6 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D6 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E6 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F6 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G6 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H6 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A7 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B7 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C7 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D7 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E7 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F7 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G7 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H7 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A8 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B8 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C8 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D8 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E8 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F8 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G8 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H8 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A9 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B9 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C9 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D9 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E9 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F9 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G9 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H9 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A10 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B10 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C10 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D10 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E10 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F10 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G10 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H10 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B11 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C11 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D11 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E11 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F11 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G11 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H11 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into A12 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into B12 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into C12 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into D12 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into E12 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 16.0 uL from A2 of Opentrons 24 Tube Rack with Generic 2 mL Screwcap on 10 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into F12 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into G12 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Dispensing 5.0 uL into H12 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 7.56 uL/sec
# Touching tip
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from B1 of 300ul Tips on 2
# Transferring 45.0 from A1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 to A1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6
# Aspirating 45.0 uL from A1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Touching tip
# Dispensing 45.0 uL into A1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 92.86 uL/sec
# Touching tip
# Aspirating 45.0 uL from B1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Touching tip
# Dispensing 45.0 uL into B1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 92.86 uL/sec
# Touching tip
# Aspirating 45.0 uL from C1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Touching tip
# Dispensing 45.0 uL into C1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 92.86 uL/sec
# Touching tip
# Aspirating 45.0 uL from D1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Touching tip
# Dispensing 45.0 uL into D1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 92.86 uL/sec
# Touching tip
# Aspirating 45.0 uL from E1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Touching tip
# Dispensing 45.0 uL into E1 of Corning 96 Well Plate 360 µL Flat on Temperature Module GEN1 on 6 at 92.86 uL/sec
# Touching tip
# Aspirating 45.0 uL from F1 of Opentrons 96 Well Aluminum Block with Generic PCR Strip 200 µL on 7 at 92.86 uL/sec
# Touching tip
# ...
# Aspirating 50.0 uL from D10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into D10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from D10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into D10 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from E10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into E10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from E10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into E10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from E10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into E10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from E10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into E10 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from F10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into F10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from F10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into F10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from F10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into F10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from F10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into F10 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from G10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into G10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from G10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into G10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from G10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into G10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from G10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into G10 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from H10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into H10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from H10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into H10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from H10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into H10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from H10 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into H10 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Returning tip
# Dropping tip into B10 of 300ul Tips on 2
# Picking up tip from C10 of 300ul Tips on 2
# Transferring 30.0 from A11 of Corning 96 Well Plate 360 µL Flat on 1 to A11 of Corning 96 Well Plate 360 µL Flat on 11
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from A11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from A11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from A11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from B11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into B11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from B11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into B11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from B11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into B11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from B11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into B11 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from C11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into C11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from C11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into C11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from C11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into C11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from C11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into C11 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from D11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into D11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from D11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into D11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from D11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into D11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from D11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into D11 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from E11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into E11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from E11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into E11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from E11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into E11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from E11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into E11 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from F11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into F11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from F11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into F11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from F11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into F11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from F11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into F11 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from G11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into G11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from G11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into G11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from G11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into G11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from G11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into G11 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from H11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into H11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from H11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into H11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from H11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into H11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from H11 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into H11 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Returning tip
# Dropping tip into C10 of 300ul Tips on 2
# Picking up tip from D10 of 300ul Tips on 2
# Transferring 30.0 from A12 of Corning 96 Well Plate 360 µL Flat on 1 to A12 of Corning 96 Well Plate 360 µL Flat on 11
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into A12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from A12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into A12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from A12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into A12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from A12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into A12 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from B12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into B12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from B12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into B12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from B12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into B12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from B12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into B12 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from C12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into C12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from C12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into C12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from C12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into C12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from C12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into C12 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from D12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into D12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from D12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into D12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from D12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into D12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from D12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into D12 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from E12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into E12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from E12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into E12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from E12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into E12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from E12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into E12 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from F12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into F12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from F12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into F12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from F12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into F12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from F12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into F12 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from G12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into G12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from G12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into G12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from G12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into G12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from G12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into G12 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from H12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into H12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from H12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into H12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 50.0 uL from H12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Dispensing 50.0 uL into H12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Aspirating 30.0 uL from H12 of Corning 96 Well Plate 360 µL Flat on 1 at 92.86 uL/sec
# Touching tip
# Dispensing 30.0 uL into H12 of Corning 96 Well Plate 360 µL Flat on 11 at 92.86 uL/sec
# Touching tip
# Returning tip
# Dropping tip into D10 of 300ul Tips on 2
